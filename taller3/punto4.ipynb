# %%
import pandas as pd
import matplotlib.pyplot as plt


diccionario={"mes":["máquina1","máquina2","máquina3","máquina4","máquina5","máquina6","máquina7"],

"Enero":[6261,7221,5709,4486,1647,5989,2850],
"Febrero":[205,7173,6517,5993,604,870,1904],
"Marzo":[6801,5094,7133,4439,1902,2198,2362],
"Abril":[4314,3046,1593,1242,5101,9754,846],
"Mayo":[9262,9015,3361,8915,9209,8396,8823],
"Junio":[6165,1014,4380,5556,814,6389,5989],
"Julio":[9277,9332,2928,3573,5167,6451,108],
"Agosto":[4593,2368,916,7995,6224,5137,9192],
"Septiembre":[1764,2904,6232,1130,261,2051,2417],
"Octubre":[1021,5397,4138,2718,6273,7871,6382],
"Noviembre":[1988,3178,7420,2767,8390,7708,2469],
"Diciembre":[6044,8315,1848,5761,3492,7600,9150]}

data=pd.DataFrame(data=diccionario,index=diccionario["mes"])
data2=data.loc[:,"Enero":]

# for i in data2.index:


#     data3=data2.loc[[i]]

media=data2.mean(axis=1)
mediana=data2.median(axis=1)
desviacion=data2.std(axis=1)
print("\nmedia: ",media,"\nmediana: ",mediana,"desviacion: ",desviacion,sep="\n")

ejey=[]

for i in data2.columns:
    ejey.append(data2.loc["máquina3",[i]].sum())
ejex=[e for e in data2.columns]
print(ejey,ejex)

plt.bar(ejex,ejey)
plt.show()
# print(data2)
# Out:
# media:
# máquina1    4807.916667
# máquina2    5338.083333
# máquina3    4347.916667
# máquina4    4547.916667
# máquina5    4090.333333
# máquina6    5867.833333
# máquina7    4374.333333
# dtype: float64
#
# mediana:
# máquina1    5318.5
# máquina2    5245.5
# máquina3    4259.0
# máquina4    4462.5
# máquina5    4296.5
# máquina6    6420.0
# máquina7    2659.5
# dtype: float64
# desviacion:
# máquina1    3049.590955
# máquina2    2839.204769
# máquina3    2255.379204
# máquina4    2442.568077
# máquina5    3087.430009
# máquina6    2797.205386
# máquina7    3344.374145
# dtype: float64
# [5709, 6517, 7133, 1593, 3361, 4380, 2928, 916, 6232, 4138, 7420, 1848] ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
